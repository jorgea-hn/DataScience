# %% [markdown]
# # Pandas
# Esta es una herramienta para la manipulacion de datos, esta construida sobre numpy y permite el analisis de datos.
# Pandas permite leer y escribir datos en diferentes formatos: csv, JSON, Excel, SQL, parquet, entre otros. tambien permite seleccionar y filtrar, fusionar, unir transformar y hacer graficas.

# %% [markdown]
# ## Instalar pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (2.1.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jorge hn\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\jorge hn\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Importando pandas

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## Series
# Es el primer tipo de dato de pandas, similar a una matriz, lo que las hace diferentes es que la serie puede tener etiquetas en los ejes y puede contener cualquier tipo de dato.

# %%
# Crear diferentes tipos de datos
labels = ['a','b','c'] # lista de eetiquetas
my_list = [10,20,30] # lista con valores
arr = np.array([10,20,30]) # Convertir ista de valores en arreglo NumPy
d = {'a':10,'b':20,'c':30} # Creacion de un diccionario

# %%
# Convertir una lista en series usando el metodo pd.Series
# observe que se crean los nombres con las posiciones de cada elemento
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# Convertir una lista en series usando el metodo pd.Series
# se puede ingresar el nombre de las posiciones
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# No es necesario ingresar la palabra de 'data =''  en el argumento
pd.Series(my_list,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# Convertir un arreglo en series indicando tambien los valores del index
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
# Convertir un diccionario en series usando el metodo pd.Series
# Como el diccionario ya tiene clave entonces se le asigna como valor de la posicion
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ## Indexacion
# Las series funcionan como una tabla hash o un diccionario

# %%
# Creacion de una serie con sus labels o indices
ser1 = pd.Series([1,2,3,4],
                index = ['USA', 'Alemania','Italia', 'Japon'])                                   
ser1
# Out:
# USA         1
# Alemania    2
# Italia      3
# Japon       4
# dtype: int64

# %%
ser1["USA"]
# Out:
# 1

# %% [markdown]
# ## DATAFRAME
# Son las estructuras mas importante en pandas, es un conjunto de series que comparten el mismo indice.

# %%
# Importar la funcion de NumPy para crear arreglos de numeros enteros
from numpy.random import randn
np.random.seed(101) # Inicializar el generador aleatorio
# Forma rapida de crear una lista de python desde strings
'A B C D E F'.split()
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
# Crear un dataframe con numeros aleatorios de 4 Columnas y 5 Filas
# Crear listas rapidamente usando la funcion split 'A B C D E'.split()
# Esto evita tener que escribir repetidamente las comas

df = pd.DataFrame(randn(6,4),
                index='A B C D E F'.split(),
                columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
# F  0.302665  1.693723 -1.706086 -1.159119

# %% [markdown]
# ### Numero de filas y columnas

# %%
df.shape
# Out:
# (6, 4)

# %% [markdown]
# ### Informacion general de los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, A to F
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       6 non-null      float64
#  1   X       6 non-null      float64
#  2   Y       6 non-null      float64
#  3   Z       6 non-null      float64
# dtypes: float64(4)
# memory usage: 240.0+ bytes

# %% [markdown]
# ### Resumen de estadistica descriptiva general

# %%
df.describe()
# Out:
#               W         X         Y         Z
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.336992  0.660424  0.092558  0.166706
# std    1.503744  1.075862  1.571280  0.839534
# min   -2.018168 -0.758872 -1.706086 -1.159119
# 25%    0.189220 -0.082455 -0.911947 -0.315794
# 50%    0.246730  0.684127 -0.159632  0.554896
# 75%    0.564005  1.455323  0.813180  0.664123
# max    2.706850  1.978757  2.605967  0.955057

# %% [markdown]
# ### Ver primeros elementos

# %%
df.head()
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ### Ver ultimos elementos

# %%
df.tail()
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
# F  0.302665  1.693723 -1.706086 -1.159119

# %% [markdown]
# ### Ver elementos aleatorios

# %%
df.sample()
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965

# %% [markdown]
# ### Seleccion

# %%
df["W"]
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# F    0.302665
# Name: W, dtype: float64

# %%
df[["W","Z"]]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509
# F  0.302665 -1.159119

# %% [markdown]
# ### Creando una nueva columna

# %%
# Nueva columna igual a la suma de otras dos
# operacion vectorizada
df['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762
# F  0.302665  1.693723 -1.706086 -1.159119 -1.403420

# %% [markdown]
# ### Eliminar columnas

# %%
df.drop("new", axis="columns", inplace=True)
#Nota: se debe colocar inplace para que se vea afectado el dataframe original
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
# F  0.302665  1.693723 -1.706086 -1.159119

# %%
df.drop('E',axis='index')
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# F  0.302665  1.693723 -1.706086 -1.159119

# %%
del df['X'] # Esta funcion es INPLACE
df
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# C -2.018168  0.528813 -0.589001
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509
# F  0.302665 -1.706086 -1.159119

# %% [markdown]
# ### Obtener los nombres de las columnas y los indices

# %%
df.columns # nombres de las columnas
# Out:
# Index(['W', 'Y', 'Z'], dtype='object')

# %%
df.index # nombres de los indices
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %% [markdown]
# ### Seleccionar filas y columnas
# * DataFrame.loc[etiqueta_fila, etiqueta_columna] <- por etiquetas
# * DataFrame.iloc[indice_fila, indice_columna] <- por indices

# %%
df.loc['A']
# Out:
# W    2.706850
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -2.018168
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %% [markdown]
# ### Seleccionar subcojuntos de filas y columnas

# %%
df.loc['B','Y'] # con etiquetas
# Out:
# -0.8480769834036315

# %%
# Mediante etiquetas
# se selecciona un subconjunto de datos que estan entre
# filas = A, B   Cols= W, Y
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# ## Seleccion condicional o filtros

# %%
df
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# C -2.018168  0.528813 -0.589001
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509
# F  0.302665 -1.706086 -1.159119

# %%
df>0
# Out:
#        W      Y      Z
# A   True   True   True
# B   True  False   True
# C  False   True  False
# D   True  False   True
# E   True   True   True
# F   True  False  False

# %%
# Esta operacion solo mostrara los valores del dataframe que cumplen la condicion
# los que no cumplen devuelve el valor NaN
df[df>0]
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118       NaN  0.605965
# C       NaN  0.528813       NaN
# D  0.188695       NaN  0.955057
# E  0.190794  2.605967  0.683509
# F  0.302665       NaN       NaN

# %%
# seleccionar todas las filas donde el valor
# que esta en la columna 'W' sea mayor que cero
df[df['W']>0]
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509
# F  0.302665 -1.706086 -1.159119

# %%
# Seleccionar las filas donde 'W' sea mayor que cero
# y de esas filas escoger los valores de la columna 'Y'
df[df['W']>0]['Y']
# Out:
# A    0.907969
# B   -0.848077
# D   -0.933237
# E    2.605967
# F   -1.706086
# Name: Y, dtype: float64

# %%
# Seleccionar las filas donde 'W' sea mayor que cero
# y de esas filas escoger los valores de las columna 'Y' y 'X'
df[df['W']>0][['Y','Z']]
# Out:
#           Y         Z
# A  0.907969  0.503826
# B -0.848077  0.605965
# D -0.933237  0.955057
# E  2.605967  0.683509
# F -1.706086 -1.159119

# %%
# Seleccionar las filas donde 'W' sea mayor que cero
# y tambien donde 'Y' sea mayor que 0.5
df[(df['W']>0) & (df['Y'] > 0.5)]
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# E  0.190794  2.605967  0.683509

# %% [markdown]
# ### query()  busqueda condicional

# %%
# seleccionar todas las filas donde el valor
# que esta en la columna 'W' sea mayor que cero

#df[df['W']>0]
df.query('W>0')
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509
# F  0.302665 -1.706086 -1.159119

# %%
# Seleccionar las filas donde 'W' sea mayor que cero
# y de esas filas escoger los valores de la columna 'Y'

#df[df['W']>0]['Y']
df.query('W>0')['Y']
# Out:
# A    0.907969
# B   -0.848077
# D   -0.933237
# E    2.605967
# F   -1.706086
# Name: Y, dtype: float64

# %%
# Seleccionar las filas donde 'W' sea mayor que cero
# y tambien donde 'Y' sea mayor que 0.5

#df[(df['W']>0) & (df['Y'] > 0.5)]
df.query('W>0 and Y>0.5')
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# E  0.190794  2.605967  0.683509

# %% [markdown]
# ## Cambio de columna de indexacion

# %%
df
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# C -2.018168  0.528813 -0.589001
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509
# F  0.302665 -1.706086 -1.159119

# %%
df = df.reset_index()
df
# Out:
#   index         W         Y         Z
# 0     A  2.706850  0.907969  0.503826
# 1     B  0.651118 -0.848077  0.605965
# 2     C -2.018168  0.528813 -0.589001
# 3     D  0.188695 -0.933237  0.955057
# 4     E  0.190794  2.605967  0.683509
# 5     F  0.302665 -1.706086 -1.159119

# %%
newind = 'CA NY WY OR CO BG'.split() # crear una lista con strings
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO', 'BG']

# %%
# Agregar la lista creaada en el paso anterior al dataframe
df['States'] = newind
df
# Out:
#   index         W         Y         Z States
# 0     A  2.706850  0.907969  0.503826     CA
# 1     B  0.651118 -0.848077  0.605965     NY
# 2     C -2.018168  0.528813 -0.589001     WY
# 3     D  0.188695 -0.933237  0.955057     OR
# 4     E  0.190794  2.605967  0.683509     CO
# 5     F  0.302665 -1.706086 -1.159119     BG

# %%
# Redefinir la columna states como el indice
df.set_index('States')
# Out:
#        index         W         Y         Z
# States
# CA         A  2.706850  0.907969  0.503826
# NY         B  0.651118 -0.848077  0.605965
# WY         C -2.018168  0.528813 -0.589001
# OR         D  0.188695 -0.933237  0.955057
# CO         E  0.190794  2.605967  0.683509
# BG         F  0.302665 -1.706086 -1.159119

# %% [markdown]
# ## GROUPBY (Permite agrupar por filas)

# %%
import pandas as pd
# Crear dataframe desde un diccionario
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB','GOOG','MSFT','FB'],
        'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah','John','Randy','David'],
        'Sales':[200,120,340,124,243,350,275,400,180]}
data
# Out:
# {'Company': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB', 'GOOG', 'MSFT', 'FB'],
#  'Person': ['Sam',
#   'Charlie',
#   'Amy',
#   'Vanessa',
#   'Carl',
#   'Sarah',
#   'John',
#   'Randy',
#   'David'],
#  'Sales': [200, 120, 340, 124, 243, 350, 275, 400, 180]}

# %%
#conversion del diccionario a dataframe
df = pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350
# 6    GOOG     John    275
# 7    MSFT    Randy    400
# 8      FB    David    180

# %%
#agrupar por Company
df.groupby('Company')

# %%
by_comp = df.groupby("Company")

# %%
# Promedio de ventas por company
by_comp.mean(numeric_only=True)
# Out:
#               Sales
# Company
# FB       257.666667
# GOOG     198.333333
# MSFT     288.000000

# %%
# agrupar por compañia y calcular el promedio por cada una
df.groupby('Company').mean(numeric_only=True)
# Out:
#               Sales
# Company
# FB       257.666667
# GOOG     198.333333
# MSFT     288.000000

# %%
# Una de las funciones mas usadas para descripcion estadistica de un dataframe
# Genera estadísticas descriptivas que resumen la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos, excluyendo los valores `` NaN``.
# by_comp.describe(include = 'all') # incluir todo
by_comp.describe()
# Out:
#         Sales
#         count        mean         std    min    25%    50%    75%    max
# Company
# FB        3.0  257.666667   85.943780  180.0  211.5  243.0  296.5  350.0
# GOOG      3.0  198.333333   77.513440  120.0  160.0  200.0  237.5  275.0
# MSFT      3.0  288.000000  145.161978  124.0  232.0  340.0  370.0  400.0

# %%
# Una de las funciones mas usadas para descripcion estadistica de un dataframe
# Genera estadísticas descriptivas que resumen la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos, excluyendo los valores `` NaN``.
# Transponer la descripcion
by_comp.describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    3.000000    3.000000    3.000000
#       mean   257.666667  198.333333  288.000000
#       std     85.943780   77.513440  145.161978
#       min    180.000000  120.000000  124.000000
#       25%    211.500000  160.000000  232.000000
#       50%    243.000000  200.000000  340.000000
#       75%    296.500000  237.500000  370.000000
#       max    350.000000  275.000000  400.000000

# %%
# Descripcion estadistica de los datos de la copmañia GOOG
by_comp.describe().transpose()['GOOG']
# Out:
# Sales  count      3.000000
#        mean     198.333333
#        std       77.513440
#        min      120.000000
#        25%      160.000000
#        50%      200.000000
#        75%      237.500000
#        max      275.000000
# Name: GOOG, dtype: float64

# %% [markdown]
# ## Pivot tables
# Esta funcionalidad permite agrupar, ordena, calcular datos y manejar datos de una forma muy similar a a que se hace en las hojas de calculo.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jorge hn\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jorge hn\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\jorge hn\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns # importar la libreria seaborn
# cargar dataset del titanic
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Haciendo el pivot a mano

# %%
# 1. Agrupar por genero
# 2. Obtener los sobrevivientes
# 3. Calcular el promedio
titanic.groupby('sex')[['survived']].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
# 1. Agrupar por genero y clase
# 2. Obtener los sobrevivientes
# 3. Calcular el promedio
# 4. Poner el resultado como una tabla (.unstack)
titanic.groupby(['sex', 'class'])['survived'].mean().unstack()
# Out:
# C:\Users\Jorge HN\AppData\Local\Temp\ipykernel_7620\1027986969.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(['sex', 'class'])['survived'].mean().unstack()
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# ### Usando pivot tables

# %%
titanic.pivot_table('survived', index='sex', columns='class')
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table('survived', index='sex', columns='class', margins=True)
# Out:
# class      First    Second     Third       All
# sex
# female  0.968085  0.921053  0.500000  0.742038
# male    0.368852  0.157407  0.135447  0.188908
# All     0.629630  0.472826  0.242363  0.383838

# %% [markdown]
# ## Concatenar, Fusionar y Unir
# Hay 3 formas de combinar dataframes, concatenar, fusionar, y unir

# %%
# DataFrames de ejemplo para concatenacion
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                        index=[4, 5, 6, 7]) 
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ### Concatenar
# Las dimesiones deben coincidir a lo largo del eje con el que se esta concatenando

# %%
# Concatenar cada dateframe verticalmente,
# ya que coinciden los nombres de las columnas

pd.concat([df1,df2,df3], axis='index')
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
#concatenar dataframe horizontalmente, 
# como no coinciden los index observar lo que ocurre

pd.concat([df1,df2,df3], axis='columns')
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# ### Fusion
# Fusiona los dataframes como una tabla SQL

# %%
# DataFrames de ejemplo para merging
left = pd.DataFrame({
    'Producto': ['Arepas', 'Banano', 'Cafe'],
    'Tienda': [1, 2, 1],
    'Ventas': [100, 200, 50]
})

right = pd.DataFrame({
    'Producto': ['Arepas', 'Banano', 'Cafe'],
    'Tienda': [1, 2, 1],
    'Inventario': [50, 100, 75]
})

# %%
left
# Out:
#   Producto  Tienda  Ventas
# 0   Arepas       1     100
# 1   Banano       2     200
# 2     Cafe       1      50

# %%
right
# Out:
#   Producto  Tienda  Inventario
# 0   Arepas       1          50
# 1   Banano       2         100
# 2     Cafe       1          75

# %%
# how='inner' utilice la intersección de las claves de ambos marcos, similar a una combinación interna de SQL; 
# las keys son comunes
pd.merge(left,right,how='inner',on='Producto')
# Out:
#   Producto  Tienda_x  Ventas  Tienda_y  Inventario
# 0   Arepas         1     100         1          50
# 1   Banano         2     200         2         100
# 2     Cafe         1      50         1          75

# %%
# fusionando comparando las mismas claves que tengan comunes
pd.merge(left, right, on=['Producto'])
# Out:
#   Producto  Tienda_x  Ventas  Tienda_y  Inventario
# 0   Arepas         1     100         1          50
# 1   Banano         2     200         2         100
# 2     Cafe         1      50         1          75

# %%
# fusionando totalmente las dos tablas con las claves
pd.merge(left, right, how='outer', on=['Producto'])
# Out:
#   Producto  Tienda_x  Ventas  Tienda_y  Inventario
# 0   Arepas         1     100         1          50
# 1   Banano         2     200         2         100
# 2     Cafe         1      50         1          75

# %%
# fusionando usando las claves de la tabla right
pd.merge(left, right, how='right', on=['Producto'])
# Out:
#   Producto  Tienda_x  Ventas  Tienda_y  Inventario
# 0   Arepas         1     100         1          50
# 1   Banano         2     200         2         100
# 2     Cafe         1      50         1          75

# %%
# fusionando usando las claves de la tabla left
pd.merge(left, right, how='left', on=['Producto'])
# Out:
#   Producto  Tienda_x  Ventas  Tienda_y  Inventario
# 0   Arepas         1     100         1          50
# 1   Banano         2     200         2         100
# 2     Cafe         1      50         1          75

# %% [markdown]
# ## Datos categoricos
# * La busqueda de datos categoricos es mas rapida
# * Ocupan menos espacio en memoria si son string
# * Se pueden obtener datos categoricos ordinales

# %% [markdown]
# ### Creacion

# %%
# Creacion de una serie de datos categoricos
cate = pd.Series(["manzana", "banano", "corozo", "manzana","pera"],
        dtype="category")
cate
# Out:
# 0    manzana
# 1     banano
# 2     corozo
# 3    manzana
# 4       pera
# dtype: category
# Categories (4, object): ['banano', 'corozo', 'manzana', 'pera']

# %%
cate.describe()
# Out:
# count           5
# unique          4
# top       manzana
# freq            2
# dtype: object

# %%
# Creando primero los datos y luego convirtiendolos en categoricos
df_cate = pd.DataFrame({"Fruta":["manzana", "banano", "corozo", "manzana","pera"]})
df_cate
# Out:
#      Fruta
# 0  manzana
# 1   banano
# 2   corozo
# 3  manzana
# 4     pera

# %%
df_cate["Fruta2"] = df_cate["Fruta"].astype('category')
df_cate
# Out:
#      Fruta   Fruta2
# 0  manzana  manzana
# 1   banano   banano
# 2   corozo   corozo
# 3  manzana  manzana
# 4     pera     pera

# %%
# Observar los tipos de datos en el dataframe
df_cate.dtypes
# Out:
# Fruta       object
# Fruta2    category
# dtype: object

# %%
# Crear los datos categoricos desde a declaracion de los datos
df_cate = pd.DataFrame({'A': list('abca'),
                        'B': list('bccd')},
                        dtype="category")
df_cate
# Out:
#    A  B
# 0  a  b
# 1  b  c
# 2  c  c
# 3  a  d

# %%
df_cate.dtypes
# Out:
# A    category
# B    category
# dtype: object

# %%
df_cate.describe()
# Out:
#         A  B
# count   4  4
# unique  3  3
# top     a  c
# freq    2  2

# %% [markdown]
# ## Categoricos ordinales

# %%
# creacion de dataframe con datos
df_cate = pd.DataFrame({'A': list('abca'),
                        'B': list('bccd')})
df_cate
# Out:
#    A  B
# 0  a  b
# 1  b  c
# 2  c  c
# 3  a  d

# %%
# Definicion de los tipos de datos y que estan en orden
df_cate["A"] = pd.Categorical(df_cate['A'],
                            categories=['a','b','c','d'],
                            ordered=True)
df_cate
# Out:
#    A  B
# 0  a  b
# 1  b  c
# 2  c  c
# 3  a  d

# %%
df_cate["A"]
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# Name: A, dtype: category
# Categories (4, object): ['a' < 'b' < 'c' < 'd']

# %%
# Los datos no tienen que ser strings para que sean categoricos
s = pd.Series([1, 2, 3, 1], dtype="category")
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
s = s.cat.set_categories([2, 3, 1],
                        ordered=True)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# dtype: category
# Categories (3, int64): [2 < 3 < 1]

# %% [markdown]
# ### Correcion de tipos de datos (CASTING)
# Los tipos de datos son principalmente:
# - numericos
# - categoricos nominales
# - categoricos ordinales
# - booleanos
# - fechas y tiempos
# - texto
# Y en ocasiones cuando trabajamos con dataframes las columnas no tienen el tipo de dato correcto.

# %%
import seaborn as sns # importar la libreria seaborn
titanic = sns.load_dataset('titanic')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 139         0       1    male  24.0      0      0  79.2000        C  First
# 548         0       3    male  33.0      1      1  20.5250        S  Third
# 32          1       3  female   NaN      0      0   7.7500        Q  Third
# 36          1       3    male   NaN      0      0   7.2292        C  Third
# 724         1       1    male  27.0      1      0  53.1000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 139    man        True    B    Cherbourg    no   True
# 548    man        True  NaN  Southampton    no  False
# 32   woman       False  NaN   Queenstown   yes   True
# 36     man        True  NaN    Cherbourg   yes   True
# 724    man        True    E  Southampton   yes  False

# %% [markdown]
# ### Casting de variables categoricas nominales

# %%
# convertir la columna sex, embarked, who, embark_town en categoricas
cols_categoricas_nom = ["sex", "embarked", "who", "embark_town"]

# ver los datos unicos de las columnas_categoricas_nom
for columna in cols_categoricas_nom:
    print(f"Valores únicos en {columna}: {titanic[columna].unique()}")
# Out:
# Valores únicos en sex: ['male' 'female']
# Valores únicos en embarked: ['S' 'C' 'Q' nan]
# Valores únicos en who: ['man' 'woman' 'child']
# Valores únicos en embark_town: ['Southampton' 'Cherbourg' 'Queenstown' nan]

# %%
titanic[cols_categoricas_nom] = titanic[cols_categoricas_nom].astype("category")

# ver los datos unicos de las columnas_categoricas_nom
for columna in cols_categoricas_nom:
    print(f"Valores únicos en {columna}: {titanic[columna].unique()}")
# Out:
# Valores únicos en sex: ['male', 'female']
# Categories (2, object): ['female', 'male']
# Valores únicos en embarked: ['S', 'C', 'Q', NaN]
# Categories (3, object): ['C', 'Q', 'S']
# Valores únicos en who: ['man', 'woman', 'child']
# Categories (3, object): ['child', 'man', 'woman']
# Valores únicos en embark_town: ['Southampton', 'Cherbourg', 'Queenstown', NaN]
# Categories (3, object): ['Cherbourg', 'Queenstown', 'Southampton']

# %% [markdown]
# ### Casting variables categoricas ordinales

# %%
cols_categoricas_ord = ["pclass", "deck"]

for columna in cols_categoricas_ord:
    print(f"Valores únicos en {columna}: {titanic[columna].unique()}")
# Out:
# Valores únicos en pclass: [3 1 2]
# Valores únicos en deck: [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic["pclass"] = pd.Categorical(titanic["pclass"],
                        categories=[3, 2, 1],
                        ordered=True)
titanic["deck"] = pd.Categorical(titanic["deck"],
                        categories=list("ABCDEFG"),
                        ordered=True)

# %%
for columna in cols_categoricas_ord:
    print(f"Valores únicos en {columna}: {titanic[columna].unique()}")
# Out:
# Valores únicos en pclass: [3, 1, 2]
# Categories (3, int64): [3 < 2 < 1]
# Valores únicos en deck: [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A' < 'B' < 'C' < 'D' < 'E' < 'F' < 'G']

# %% [markdown]
# ### Casting variables booleanas

# %%
columnas_bool = ["alive", "alone", "survived"]

titanic[columnas_bool] = titanic[columnas_bool].astype("bool")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    bool
#  1   pclass       891 non-null    category
#  2   sex          891 non-null    category
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    category
#  8   class        891 non-null    category
#  9   who          891 non-null    category
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    category
#  13  alive        891 non-null    bool
#  14  alone        891 non-null    bool
# dtypes: bool(4), category(7), float64(2), int64(2)
# memory usage: 38.7 KB

# %% [markdown]
# ## Datos faltantes (Mising data)

# %%
# Declaracion de data frame con algunos datos faltantes
# NaN = Not a Number
df = pd.DataFrame({'A':[1,2,np.nan],
                'B':[5,np.nan,np.nan],
                'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# ### Detectar si faltan datos

# %%
# verificar cuales valores son NaN o nulos (Null)
df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
# Verificar si hay datos faltantes por columna
df.isna().any()
# Out:
# A     True
# B     True
# C    False
# dtype: bool

# %% [markdown]
# ### Numero de datos faltantes

# %%
# Numero de datos faltantes por columna
df.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %% [markdown]
# ### Eliminar datos faltantes

# %%
# Eliminar todas las filas que tengan datos faltantes
df.dropna(axis='index') # cuando son filas no es neceario escribir axis=0
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
# Eliminar todas las columnas que tengan datos faltantes
df.dropna(axis='columns')
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
# eliminar las filas que tengas 2 o mas valores NaN
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %% [markdown]
# ### Reemplazar datos faltantes

# %%
# Llenar los datos faltantes con el dato que nos interese
df.fillna(value='Llenar Valores') # llenar los espacios con un string
                            # puede ser una palabra, numero , etc
# Out:
#                 A               B  C
# 0             1.0             5.0  1
# 1             2.0  Llenar Valores  2
# 2  Llenar Valores  Llenar Valores  3

# %% [markdown]
# #### Llenar los datos faltantes con un dato especifico

# %%
# Llenar los datos faltantes con el dato que nos interese
df.fillna(value=99) # llenar los espacios con un numero
# Out:
#       A     B  C
# 0   1.0   5.0  1
# 1   2.0  99.0  2
# 2  99.0  99.0  3

# %% [markdown]
# #### Llenar los datos faltantes con el promedio

# %%
# Llenar los datos faltantes con el promedio de esa columna
df['A'].fillna(value=df['A'].mean())

# %% [markdown]
# #### Llenar los datos faltantes con el promedio de una columna especifica

# %%
# Llenar los datos faltantes con el promedio de esa columna
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# ####  Llenar los datos faltantes con el promedio de cada columna

# %%
# Llenar los datos faltantes con el promedio de cada columna
df.fillna(value=df.mean())
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  1.5  5.0  3

# %% [markdown]
# ### Datos unicos (Unique values)

# %%
import pandas as pd
# crear un dataframe
df = pd.DataFrame({'col1':[1,2,3,4],
                    'col2':[444,555,666,444],
                    'col3':['abc','def','ghi','xyz']})
df.head() # solamente mostrar los primeros elementos del dataframe
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
# valores unicos de la columna col2
df['col2'].unique()
# Out:
# array([444, 555, 666], dtype=int64)

# %%
# Numero de valores unicos en el dataframe
df['col2'].nunique()
# Out:
# 3

# %%
# contar cuanto se repiten cada uno de los valores
df['col2'].value_counts()
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %% [markdown]
# ### Datos duplicados

# %%
datos = {'nombre': ['Jaime', 'Juan', 'Roberto', 'Juan'],
            'edad': [18, 20, 22, 20],
            'trabajo': ['Asistente', 'Manager', 'Cientifico', 'Manager']}
df_dup = pd.DataFrame(datos)
df_dup
# Out:
#     nombre  edad     trabajo
# 0    Jaime    18   Asistente
# 1     Juan    20     Manager
# 2  Roberto    22  Cientifico
# 3     Juan    20     Manager

# %%
# Metodo para detectar los datos duplicados
# me sirve para ver si existen registros duplicados
df_dup.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
# Contar cuantos datos duplicados existen
df_dup.duplicated().sum()
# Out:
# 1

# %%
# Para remover los datos duplicados
df_dup.drop_duplicates()
# Out:
#     nombre  edad     trabajo
# 0    Jaime    18   Asistente
# 1     Juan    20     Manager
# 2  Roberto    22  Cientifico

# %%
# El metodo drop_duplicates entrega el data frame sin duplicados
# Pero la funcion no es inplace, osea que el dataframe original sigue igual
df_dup
# Out:
#     nombre  edad     trabajo
# 0    Jaime    18   Asistente
# 1     Juan    20     Manager
# 2  Roberto    22  Cientifico
# 3     Juan    20     Manager

# %%
df_dup.drop_duplicates(inplace=True)
df_dup
# Out:
#     nombre  edad     trabajo
# 0    Jaime    18   Asistente
# 1     Juan    20     Manager
# 2  Roberto    22  Cientifico

# %% [markdown]
# ### Duplicados por columna

# %%
frame_datos = {'nombre': ['Jaime', 'Juan', 'Roberto', 'Juan'],
                'edad': [18, 20, 22, 21],
                'trabajo': ['Asistente', 'Manager', 'Cientifico', 'Profesor']}
df_dup = pd.DataFrame(frame_datos)
df_dup
# Out:
#     nombre  edad     trabajo
# 0    Jaime    18   Asistente
# 1     Juan    20     Manager
# 2  Roberto    22  Cientifico
# 3     Juan    21    Profesor

# %%
# recordar que estas funciones no son inplace
df_dup.drop_duplicates(['nombre'])
# Out:
#     nombre  edad     trabajo
# 0    Jaime    18   Asistente
# 1     Juan    20     Manager
# 2  Roberto    22  Cientifico

# %% [markdown]
# ### Outliers
# Una de las formas de eliminar los outliers es identificando cual sera el rango en el que queremos nuestros datos y limitar los datos entre ese rango

# %%
import seaborn as sns # importar la libreria seaborn
# cargar dataset del titanic
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
edad = titanic['age']
edad
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
# Cual es la edad maxima
edad.max()
# Out:
# 80.0

# %%
# Cual es la edad Minima
edad.min()
# Out:
# 0.42

# %%
# Delimitaremos la edad entre 1 y 70 por fines de ejercicio
edad = edad.clip(lower=1,upper = 70)

# %%
edad.max()
# Out:
# 70.0

# %%
edad.min()
# Out:
# 1.0

# %% [markdown]
# ### Tablas de contingencia (Two way tables)

# %%
# Crear Datos
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['infantry', 'infantry', 'cavalry', 'cavalry', 'infantry', 'infantry', 'cavalry', 'cavalry','infantry', 'infantry', 'cavalry', 'cavalry'], 
        'experience': ['veteran', 'rookie', 'veteran', 'rookie', 'veteran', 'rookie', 'veteran', 'rookie','veteran', 'rookie', 'veteran', 'rookie'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}
df = pd.DataFrame(raw_data, columns = ['regiment', 'company', 'experience', 'name', 'preTestScore', 'postTestScore'])
df
# Out:
#       regiment   company experience      name  preTestScore  postTestScore
# 0   Nighthawks  infantry    veteran    Miller             4             25
# 1   Nighthawks  infantry     rookie  Jacobson            24             94
# 2   Nighthawks   cavalry    veteran       Ali            31             57
# 3   Nighthawks   cavalry     rookie    Milner             2             62
# 4     Dragoons  infantry    veteran     Cooze             3             70
# 5     Dragoons  infantry     rookie     Jacon             4             25
# 6     Dragoons   cavalry    veteran    Ryaner            24             94
# 7     Dragoons   cavalry     rookie      Sone            31             57
# 8       Scouts  infantry    veteran     Sloan             2             62
# 9       Scouts  infantry     rookie     Piger             3             70
# 10      Scouts   cavalry    veteran     Riani             2             62
# 11      Scouts   cavalry     rookie       Ali             3             70

# %%
# Tabla de contingencia por compañía y regimiento
pd.crosstab(df['regiment'], df['company'], margins=True)
# Out:
# company     cavalry  infantry  All
# regiment
# Dragoons          2         2    4
# Nighthawks        2         2    4
# Scouts            2         2    4
# All               6         6   12

# %%
# Tabla de contingencia de compañia y experiencia por regimiento
pd.crosstab([df['company'], df['experience']], df['regiment'],  margins=True)
# Out:
# regiment             Dragoons  Nighthawks  Scouts  All
# company  experience
# cavalry  rookie             1           1       1    3
#          veteran            1           1       1    3
# infantry rookie             1           1       1    3
#          veteran            1           1       1    3
# All                         4           4       4   12

# %% [markdown]
# ### Metodos y funciones en pandas

# %%
import pandas as pd
# crear un dataframe
df = pd.DataFrame({'col1':[1,2,3,4],
                    'col2':[444,555,666,444],
                    'col3':['mama   ','  papa','   HIJO  ','HiJa']})
df.head() # solamente mostrar los primeros elementos del dataframe
# Out:
#    col1  col2       col3
# 0     1   444    mama
# 1     2   555       papa
# 2     3   666     HIJO
# 3     4   444       HiJa

# %% [markdown]
# #### sum()
# Suma el total de cada columna

# %%
# Suma total de cada Columna, si es categorico no lo suma
df.sum()
# Out:
# col1                            10
# col2                          2109
# col3    mama     papa   HIJO  HiJa
# dtype: object

# %% [markdown]
# #### min() y max()

# %%
# Valor Minimo cada Columna
print(df.min())
print(df.max())
# Out:
# col1            1
# col2          444
# col3       HIJO
# dtype: object
# col1          4
# col2        666
# col3    mama
# dtype: object

# %% [markdown]
# ### Metodos de informacion general

# %%
# Cargar la base de datos 'mpg' de la libreria seaborn
import seaborn as sns

# los datos se cargan en un dataframe
data = sns.load_dataset('mpg')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# #### head()

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# #### describe()

# %%
data.describe() # ver datos estadisticos de las columnas numericas
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
data.describe(include = 'all') # ver todos los datos incluidos los categoricos
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# unique           NaN         NaN      3         305
# top              NaN         NaN    usa  ford pinto
# freq             NaN         NaN    249           6
# mean       15.568090   76.010050    NaN         NaN
# std         2.757689    3.697627    NaN         NaN
# min         8.000000   70.000000    NaN         NaN
# 25%        13.825000   73.000000    NaN         NaN
# 50%        15.500000   76.000000    NaN         NaN
# 75%        17.175000   79.000000    NaN         NaN
# max        24.800000   82.000000    NaN         NaN

# %%
# Descripcion de una sola columna
data['cylinders'].describe()
# Out:
# count    398.000000
# mean       5.454774
# std        1.701004
# min        3.000000
# 25%        4.000000
# 50%        4.000000
# 75%        8.000000
# max        8.000000
# Name: cylinders, dtype: float64

# %% [markdown]
# ### Estadistica descriptiva
# Estos calculos se hacen siempre en columnas, si se require hacer por filas, se debe especificar el parametro axis=1
#
# Ejemplo:
# * calculo por columna: df.mean()
# * calculo por fila   : df.mean(axis="columns")

# %% [markdown]
# #### Medidas  de centralizacion

# %%
# Se tomara la columna 'mpg' para realizar los calculos
X = data['mpg']
type(X)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Media

# %%
X.mean()
# Out:
# 23.514572864321607

# %% [markdown]
# #### Mediana

# %%
# Mediana
X.median()
# Out:
# 23.0

# %% [markdown]
# #### Moda

# %%
# Moda
X.mode()
# Out:
# 0    13.0
# Name: mpg, dtype: float64

# %% [markdown]
# #### Cuartiles

# %%
# Valores de los cuartiles
X.quantile([0, .25, .5, .75, 1])
# Out:
# 0.00     9.0
# 0.25    17.5
# 0.50    23.0
# 0.75    29.0
# 1.00    46.6
# Name: mpg, dtype: float64

# %% [markdown]
# ### Medidas de dispersion

# %% [markdown]
# #### Varianza

# %%
# Varianza
X.var() #unbiased Normalized by N-1 by default.
# Out:
# 61.089610774274405

# %% [markdown]
# #### Desviacion estandar

# %%
# Desviacion tipica o desviacion estandard
X.std()
# Out:
# 7.815984312565782

# %% [markdown]
# #### Coeficiente de variacion

# %%
# Coeficiente de Variacion
X.std()/X.mean()
# Out:
# 0.33238895546450203

# %% [markdown]
# ### Medidas de asimetria

# %% [markdown]
# #### Asimetria de Fisher(skewness)
# Es la medida que indica la simetria de la distribucion de una variable respecto a la media aritmetica, sin necesidad de graficas.
# Los coeficientes indican si hay el mismo numero de elementos a la izquierda y derecha de la media
#
# Existen 3 tipos de curva de distribucion:
# * Asimetria negativa: La cola de la distribucion se alarga a valores inferiores a la media
# * Simetrica: Hay el mismo numero de elementos de izquierda y derecha de la media.
# * Asimetrica positiva: La cola de distribucion se alarga a valores superiores a la media.

# %%
#unbiased skew, Normalized by N-1
X.skew()
# Out:
# 0.45706634399491913

# %% [markdown]
# #### Curtosis
# Esta medida determina el grado de concentracion que presentan los valores en la region central de la distribucion.
# Por medio del Coeficiente de Curtosis, podemos identificar si existe una gran concentración de valores (Leptocúrtica), una concentración normal (Mesocúrtica) ó una baja concentración (Platicúrtica).

# %%
# unbiased kurtosis over requested axis using Fisher's definition
X.kurtosis()
# Out:
# -0.5107812652123154

# %% [markdown]
# ### Covarianza

# %%
s1 = pd.Series(np.random.randn(1000))
s2 = pd.Series(np.random.randn(1000))

# %%
s1.cov(s2)
# Out:
# -0.025094639027196365

# %%
# Numpy
np.cov(s1,s2)
# Out:
# array([[ 0.95048876, -0.02509464],
#        [-0.02509464,  0.97241405]])

# %%
frame = pd.DataFrame(np.random.randn(1000, 5),columns=['a', 'b', 'c', 'd', 'e'])
frame.head()
# Out:
#           a         b         c         d         e
# 0  0.499849 -0.094094  1.604184 -1.080716  1.031231
# 1  0.776868 -0.056033  0.590348 -0.022956  0.031928
# 2 -1.448370  0.083080  0.559249 -0.902921 -0.222358
# 3 -1.042227  1.045355 -0.168918  0.361434  0.150148
# 4 -1.428764 -1.904445 -2.016604  1.077732 -0.853357

# %%
frame.cov()
# Out:
#           a         b         c         d         e
# a  1.009833 -0.020353  0.011463 -0.008649 -0.090720
# b -0.020353  1.015555 -0.070017 -0.000055  0.019908
# c  0.011463 -0.070017  1.022689 -0.035151 -0.023407
# d -0.008649 -0.000055 -0.035151  1.001558  0.025479
# e -0.090720  0.019908 -0.023407  0.025479  0.979957

# %% [markdown]
# ### Correlacion
# Existen varios metodos de correlacion
#
# * Pearson (predeterminado)
# * kendall
# * spearman

# %%
#  Creacion de dataframe con datos aleatorios
frame = pd.DataFrame(np.random.randn(1000, 5),
                    columns=['a', 'b', 'c', 'd', 'e'])
frame.head()
# Out:
#           a         b         c         d         e
# 0  0.207381  1.140107  0.291974 -1.027103  0.806736
# 1 -1.296042 -0.506816 -0.610655  0.174875 -0.023277
# 2  0.097634  0.089146  2.039174  1.950184 -1.713418
# 3  1.854029 -0.337418 -1.075806  0.006662  1.396997
# 4  0.813020 -0.638845 -0.038826 -0.304283  0.758953

# %% [markdown]
# #### Entre series

# %%
frame['a'].corr(frame['b']) # Pearson que es el predeterminado
# Out:
# 0.056125393678341774

# %%
pip install scipy
# Out:
# Collecting scipyNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/c6/a1/357e4cd43af2748e1e0407ae0e9a5ea8aaaa6b702833c81be11670dcbad8/scipy-1.11.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading scipy-1.11.4-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------------------- ------------------- 30.7/60.4 kB 81.9 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/60.4 kB 81.9 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/60.4 kB 81.9 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 104.8 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 118.9 kB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\jorge hn\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.2)
# Downloading scipy-1.11.4-cp312-cp312-win_amd64.whl (43.7 MB)
#    ---------------------------------------- 0.0/43.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/43.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/43.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/43.7 MB 325.1 kB/s eta 0:02:15
#    ---------------------------------------- 0.0/43.7 MB 393.8 kB/s eta 0:01:51
#    ---------------------------------------- 0.1/43.7 MB 328.2 kB/s eta 0:02:14
#    ---------------------------------------- 0.1/43.7 MB 416.7 kB/s eta 0:01:45
#    ---------------------------------------- 0.1/43.7 MB 348.6 kB/s eta 0:02:06
#    ---------------------------------------- 0.1/43.7 MB 344.8 kB/s eta 0:02:07
#    ---------------------------------------- 0.1/43.7 MB 344.8 kB/s eta 0:02:07
#    ---------------------------------------- 0.1/43.7 MB 300.4 kB/s eta 0:02:26
#    ---------------------------------------- 0.1/43.7 MB 300.4 kB/s eta 0:02:26
#    ---------------------------------------- 0.1/43.7 MB 300.4 kB/s eta 0:02:26
#    ---------------------------------------- 0.1/43.7 MB 274.5 kB/s eta 0:02:39
#    ---------------------------------------- 0.1/43.7 MB 274.5 kB/s eta 0:02:39
#    ---------------------------------------- 0.1/43.7 MB 274.5 kB/s eta 0:02:39
#    ---------------------------------------- 0.2/43.7 MB 239.6 kB/s eta 0:03:02
#    ---------------------------------------- 0.2/43.7 MB 239.6 kB/s eta 0:03:02
#    ---------------------------------------- 0.2/43.7 MB 239.6 kB/s eta 0:03:02
#    ---------------------------------------- 0.2/43.7 MB 239.6 kB/s eta 0:03:02
#    ---------------------------------------- 0.2/43.7 MB 201.5 kB/s eta 0:03:37
#    ---------------------------------------- 0.2/43.7 MB 201.5 kB/s eta 0:03:37
#    ---------------------------------------- 0.2/43.7 MB 201.5 kB/s eta 0:03:37
#    ---------------------------------------- 0.2/43.7 MB 196.5 kB/s eta 0:03:42
#    ---------------------------------------- 0.2/43.7 MB 196.5 kB/s eta 0:03:42
#    ---------------------------------------- 0.2/43.7 MB 196.5 kB/s eta 0:03:42
#    ---------------------------------------- 0.2/43.7 MB 196.5 kB/s eta 0:03:42
#    ---------------------------------------- 0.2/43.7 MB 175.3 kB/s eta 0:04:09
#    ---------------------------------------- 0.2/43.7 MB 175.3 kB/s eta 0:04:09
#    ---------------------------------------- 0.2/43.7 MB 175.3 kB/s eta 0:04:09
#    ---------------------------------------- 0.2/43.7 MB 174.1 kB/s eta 0:04:10
#    ---------------------------------------- 0.2/43.7 MB 174.1 kB/s eta 0:04:10
#    ---------------------------------------- 0.2/43.7 MB 174.1 kB/s eta 0:04:10
#    ---------------------------------------- 0.2/43.7 MB 174.1 kB/s eta 0:04:10
#    ---------------------------------------- 0.2/43.7 MB 165.6 kB/s eta 0:04:23
#    ---------------------------------------- 0.2/43.7 MB 165.6 kB/s eta 0:04:23
#    ---------------------------------------- 0.2/43.7 MB 165.6 kB/s eta 0:04:23
#    ---------------------------------------- 0.3/43.7 MB 167.2 kB/s eta 0:04:20
#    ---------------------------------------- 0.3/43.7 MB 173.4 kB/s eta 0:04:11
#    ---------------------------------------- 0.3/43.7 MB 173.4 kB/s eta 0:04:11
#    ---------------------------------------- 0.3/43.7 MB 171.5 kB/s eta 0:04:14
#    ---------------------------------------- 0.3/43.7 MB 180.4 kB/s eta 0:04:01
#    ---------------------------------------- 0.3/43.7 MB 180.4 kB/s eta 0:04:01
#    ---------------------------------------- 0.3/43.7 MB 179.8 kB/s eta 0:04:02
#    ---------------------------------------- 0.3/43.7 MB 184.9 kB/s eta 0:03:55
#    ---------------------------------------- 0.3/43.7 MB 184.9 kB/s eta 0:03:55
#    ---------------------------------------- 0.4/43.7 MB 188.0 kB/s eta 0:03:51
#    ---------------------------------------- 0.4/43.7 MB 187.2 kB/s eta 0:03:52
#    ---------------------------------------- 0.4/43.7 MB 187.2 kB/s eta 0:03:52
#    ---------------------------------------- 0.4/43.7 MB 183.7 kB/s eta 0:03:56
#    ---------------------------------------- 0.4/43.7 MB 188.6 kB/s eta 0:03:50
#    ---------------------------------------- 0.4/43.7 MB 188.6 kB/s eta 0:03:50
#    ---------------------------------------- 0.4/43.7 MB 188.6 kB/s eta 0:03:50
#    ---------------------------------------- 0.4/43.7 MB 182.5 kB/s eta 0:03:58
#    ---------------------------------------- 0.4/43.7 MB 182.5 kB/s eta 0:03:58
#    ---------------------------------------- 0.4/43.7 MB 182.5 kB/s eta 0:03:58
#    ---------------------------------------- 0.4/43.7 MB 179.1 kB/s eta 0:04:02
#    ---------------------------------------- 0.4/43.7 MB 179.1 kB/s eta 0:04:02
#    ---------------------------------------- 0.5/43.7 MB 181.8 kB/s eta 0:03:59
#    ---------------------------------------- 0.5/43.7 MB 181.8 kB/s eta 0:03:59
#    ---------------------------------------- 0.5/43.7 MB 178.0 kB/s eta 0:04:04
#    ---------------------------------------- 0.5/43.7 MB 178.0 kB/s eta 0:04:04
#    ---------------------------------------- 0.5/43.7 MB 177.3 kB/s eta 0:04:04
#    ---------------------------------------- 0.5/43.7 MB 177.3 kB/s eta 0:04:04
#    ---------------------------------------- 0.5/43.7 MB 175.0 kB/s eta 0:04:08
#    ---------------------------------------- 0.5/43.7 MB 175.0 kB/s eta 0:04:08
#    ---------------------------------------- 0.5/43.7 MB 175.0 kB/s eta 0:04:08
#    ---------------------------------------- 0.5/43.7 MB 175.0 kB/s eta 0:04:08
#    ---------------------------------------- 0.5/43.7 MB 175.0 kB/s eta 0:04:08
#    ---------------------------------------- 0.5/43.7 MB 168.1 kB/s eta 0:04:18
#    ---------------------------------------- 0.5/43.7 MB 168.1 kB/s eta 0:04:18
#    ---------------------------------------- 0.5/43.7 MB 168.1 kB/s eta 0:04:18
#    ---------------------------------------- 0.5/43.7 MB 167.1 kB/s eta 0:04:19
#    ---------------------------------------- 0.5/43.7 MB 167.1 kB/s eta 0:04:19
#    ---------------------------------------- 0.5/43.7 MB 166.2 kB/s eta 0:04:20
#     --------------------------------------- 0.6/43.7 MB 169.3 kB/s eta 0:04:15
#     --------------------------------------- 0.6/43.7 MB 169.3 kB/s eta 0:04:15
#     --------------------------------------- 0.6/43.7 MB 170.0 kB/s eta 0:04:14
#     --------------------------------------- 0.6/43.7 MB 170.0 kB/s eta 0:04:14
#     --------------------------------------- 0.6/43.7 MB 170.6 kB/s eta 0:04:13
#     --------------------------------------- 0.6/43.7 MB 170.6 kB/s eta 0:04:13
#     --------------------------------------- 0.6/43.7 MB 171.8 kB/s eta 0:04:11
#     --------------------------------------- 0.6/43.7 MB 171.8 kB/s eta 0:04:11
#     --------------------------------------- 0.6/43.7 MB 171.8 kB/s eta 0:04:11
#     --------------------------------------- 0.6/43.7 MB 171.8 kB/s eta 0:04:11
#     --------------------------------------- 0.6/43.7 MB 164.5 kB/s eta 0:04:23
#     --------------------------------------- 0.6/43.7 MB 164.5 kB/s eta 0:04:23
#     --------------------------------------- 0.6/43.7 MB 164.5 kB/s eta 0:04:23
#     --------------------------------------- 0.6/43.7 MB 163.2 kB/s eta 0:04:25
#     --------------------------------------- 0.6/43.7 MB 163.2 kB/s eta 0:04:25
#     --------------------------------------- 0.6/43.7 MB 163.2 kB/s eta 0:04:25
#     --------------------------------------- 0.7/43.7 MB 161.9 kB/s eta 0:04:27
#     --------------------------------------- 0.7/43.7 MB 161.9 kB/s eta 0:04:27
#     --------------------------------------- 0.7/43.7 MB 160.7 kB/s eta 0:04:28
#     --------------------------------------- 0.7/43.7 MB 160.7 kB/s eta 0:04:28
#     --------------------------------------- 0.7/43.7 MB 161.4 kB/s eta 0:04:27
#     --------------------------------------- 0.7/43.7 MB 161.4 kB/s eta 0:04:27
#     --------------------------------------- 0.7/43.7 MB 159.2 kB/s eta 0:04:31
#     --------------------------------------- 0.7/43.7 MB 159.2 kB/s eta 0:04:31
#     --------------------------------------- 0.7/43.7 MB 159.2 kB/s eta 0:04:31
#     --------------------------------------- 0.7/43.7 MB 159.3 kB/s eta 0:04:30
#     --------------------------------------- 0.7/43.7 MB 159.3 kB/s eta 0:04:30
#     --------------------------------------- 0.7/43.7 MB 159.3 kB/s eta 0:04:30
#     --------------------------------------- 0.8/43.7 MB 160.5 kB/s eta 0:04:28
#     --------------------------------------- 0.8/43.7 MB 163.3 kB/s eta 0:04:24
#     --------------------------------------- 0.8/43.7 MB 163.3 kB/s eta 0:04:24
#     --------------------------------------- 0.8/43.7 MB 163.3 kB/s eta 0:04:23
#     --------------------------------------- 0.8/43.7 MB 163.3 kB/s eta 0:04:23
#     --------------------------------------- 0.8/43.7 MB 163.8 kB/s eta 0:04:22
#     --------------------------------------- 0.8/43.7 MB 163.8 kB/s eta 0:04:22
#     --------------------------------------- 0.8/43.7 MB 163.8 kB/s eta 0:04:22
#     --------------------------------------- 0.8/43.7 MB 163.8 kB/s eta 0:04:22
#     --------------------------------------- 0.8/43.7 MB 164.9 kB/s eta 0:04:21
#     --------------------------------------- 0.8/43.7 MB 164.9 kB/s eta 0:04:21
#     --------------------------------------- 0.8/43.7 MB 163.3 kB/s eta 0:04:23
#     --------------------------------------- 0.8/43.7 MB 163.3 kB/s eta 0:04:23
#     --------------------------------------- 0.9/43.7 MB 164.8 kB/s eta 0:04:21
#     --------------------------------------- 0.9/43.7 MB 164.8 kB/s eta 0:04:21
#     --------------------------------------- 0.9/43.7 MB 164.8 kB/s eta 0:04:20
#     --------------------------------------- 0.9/43.7 MB 166.2 kB/s eta 0:04:18
#     --------------------------------------- 0.9/43.7 MB 168.1 kB/s eta 0:04:15
#     --------------------------------------- 1.0/43.7 MB 170.8 kB/s eta 0:04:11
#     --------------------------------------- 1.0/43.7 MB 170.8 kB/s eta 0:04:11
#     --------------------------------------- 1.0/43.7 MB 173.9 kB/s eta 0:04:06
#     --------------------------------------- 1.0/43.7 MB 173.9 kB/s eta 0:04:06
#     --------------------------------------- 1.0/43.7 MB 174.2 kB/s eta 0:04:06
#     --------------------------------------- 1.0/43.7 MB 174.2 kB/s eta 0:04:06
#     --------------------------------------- 1.0/43.7 MB 173.1 kB/s eta 0:04:07
#     --------------------------------------- 1.0/43.7 MB 173.1 kB/s eta 0:04:07
#     --------------------------------------- 1.0/43.7 MB 173.1 kB/s eta 0:04:07
#     --------------------------------------- 1.0/43.7 MB 173.1 kB/s eta 0:04:07
#     --------------------------------------- 1.0/43.7 MB 170.7 kB/s eta 0:04:11
#     --------------------------------------- 1.0/43.7 MB 170.7 kB/s eta 0:04:11
#     --------------------------------------- 1.0/43.7 MB 168.4 kB/s eta 0:04:14
#     --------------------------------------- 1.0/43.7 MB 168.4 kB/s eta 0:04:14
#     --------------------------------------- 1.0/43.7 MB 168.4 kB/s eta 0:04:14
#     --------------------------------------- 1.0/43.7 MB 168.4 kB/s eta 0:04:14
#     --------------------------------------- 1.0/43.7 MB 168.4 kB/s eta 0:04:14
#     --------------------------------------- 1.0/43.7 MB 168.4 kB/s eta 0:04:14
#     --------------------------------------- 1.0/43.7 MB 168.4 kB/s eta 0:04:14
#     --------------------------------------- 1.1/43.7 MB 163.4 kB/s eta 0:04:22
#     --------------------------------------- 1.1/43.7 MB 163.4 kB/s eta 0:04:22
#     --------------------------------------- 1.1/43.7 MB 162.7 kB/s eta 0:04:23
#     --------------------------------------- 1.1/43.7 MB 162.7 kB/s eta 0:04:23
#    - -------------------------------------- 1.1/43.7 MB 163.1 kB/s eta 0:04:22
#    - -------------------------------------- 1.1/43.7 MB 163.1 kB/s eta 0:04:22
#    - -------------------------------------- 1.1/43.7 MB 163.8 kB/s eta 0:04:21
#    - -------------------------------------- 1.1/43.7 MB 163.8 kB/s eta 0:04:21
#    - -------------------------------------- 1.1/43.7 MB 163.5 kB/s eta 0:04:21
#    - -------------------------------------- 1.1/43.7 MB 164.9 kB/s eta 0:04:19
#    - -------------------------------------- 1.2/43.7 MB 164.2 kB/s eta 0:04:20
#    - -------------------------------------- 1.2/43.7 MB 164.2 kB/s eta 0:04:20
#    - -------------------------------------- 1.2/43.7 MB 164.2 kB/s eta 0:04:20
#    - -------------------------------------- 1.2/43.7 MB 164.2 kB/s eta 0:04:20
#    - -------------------------------------- 1.2/43.7 MB 163.5 kB/s eta 0:04:21
#    - -------------------------------------- 1.2/43.7 MB 163.5 kB/s eta 0:04:21
#    - -------------------------------------- 1.2/43.7 MB 163.5 kB/s eta 0:04:21
#    - -------------------------------------- 1.2/43.7 MB 162.8 kB/s eta 0:04:22
#    - -------------------------------------- 1.2/43.7 MB 162.8 kB/s eta 0:04:22
#    - -------------------------------------- 1.2/43.7 MB 162.8 kB/s eta 0:04:22
#    - -------------------------------------- 1.2/43.7 MB 161.8 kB/s eta 0:04:23
#    - -------------------------------------- 1.2/43.7 MB 162.8 kB/s eta 0:04:22
#    - -------------------------------------- 1.2/43.7 MB 163.2 kB/s eta 0:04:21
#    - -------------------------------------- 1.3/43.7 MB 164.9 kB/s eta 0:04:18
#    - -------------------------------------- 1.3/43.7 MB 166.5 kB/s eta 0:04:15
#    - -------------------------------------- 1.3/43.7 MB 166.8 kB/s eta 0:04:15
#    - -------------------------------------- 1.3/43.7 MB 168.1 kB/s eta 0:04:13
#    - -------------------------------------- 1.3/43.7 MB 168.1 kB/s eta 0:04:13
#    - -------------------------------------- 1.3/43.7 MB 168.1 kB/s eta 0:04:13
#    - -------------------------------------- 1.3/43.7 MB 169.7 kB/s eta 0:04:10
#    - -------------------------------------- 1.4/43.7 MB 171.0 kB/s eta 0:04:08
#    - -------------------------------------- 1.4/43.7 MB 171.0 kB/s eta 0:04:08
#    - -------------------------------------- 1.4/43.7 MB 170.6 kB/s eta 0:04:09
#    - -------------------------------------- 1.4/43.7 MB 170.6 kB/s eta 0:04:09
#    - -------------------------------------- 1.4/43.7 MB 171.4 kB/s eta 0:04:07
#    - -------------------------------------- 1.4/43.7 MB 172.9 kB/s eta 0:04:05
#    - -------------------------------------- 1.4/43.7 MB 172.9 kB/s eta 0:04:05
#    - -------------------------------------- 1.4/43.7 MB 173.8 kB/s eta 0:04:04
#    - -------------------------------------- 1.5/43.7 MB 173.7 kB/s eta 0:04:04
#    - -------------------------------------- 1.5/43.7 MB 173.7 kB/s eta 0:04:04
#    - -------------------------------------- 1.5/43.7 MB 174.5 kB/s eta 0:04:03
#    - -------------------------------------- 1.5/43.7 MB 174.5 kB/s eta 0:04:03
#    - -------------------------------------- 1.5/43.7 MB 174.5 kB/s eta 0:04:03
#    - -------------------------------------- 1.5/43.7 MB 174.5 kB/s eta 0:04:03
#    - -------------------------------------- 1.5/43.7 MB 172.5 kB/s eta 0:04:05
#    - -------------------------------------- 1.5/43.7 MB 172.5 kB/s eta 0:04:05
#    - -------------------------------------- 1.5/43.7 MB 172.5 kB/s eta 0:04:05
#    - -------------------------------------- 1.5/43.7 MB 171.8 kB/s eta 0:04:06
#    - -------------------------------------- 1.5/43.7 MB 171.8 kB/s eta 0:04:06
#    - -------------------------------------- 1.5/43.7 MB 171.8 kB/s eta 0:04:06
#    - -------------------------------------- 1.5/43.7 MB 171.8 kB/s eta 0:04:06
#    - -------------------------------------- 1.5/43.7 MB 170.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.5/43.7 MB 170.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.5/43.7 MB 170.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.5/43.7 MB 169.2 kB/s eta 0:04:10
#    - -------------------------------------- 1.5/43.7 MB 169.2 kB/s eta 0:04:10
#    - -------------------------------------- 1.5/43.7 MB 169.2 kB/s eta 0:04:10
#    - -------------------------------------- 1.5/43.7 MB 169.2 kB/s eta 0:04:10
#    - -------------------------------------- 1.6/43.7 MB 168.6 kB/s eta 0:04:11
#    - -------------------------------------- 1.6/43.7 MB 168.6 kB/s eta 0:04:11
#    - -------------------------------------- 1.6/43.7 MB 168.6 kB/s eta 0:04:11
#    - -------------------------------------- 1.6/43.7 MB 168.6 kB/s eta 0:04:11
#    - -------------------------------------- 1.6/43.7 MB 168.6 kB/s eta 0:04:11
#    - -------------------------------------- 1.6/43.7 MB 166.3 kB/s eta 0:04:14
#    - -------------------------------------- 1.6/43.7 MB 166.3 kB/s eta 0:04:14
#    - -------------------------------------- 1.6/43.7 MB 167.1 kB/s eta 0:04:13
#    - -------------------------------------- 1.6/43.7 MB 167.1 kB/s eta 0:04:13
#    - -------------------------------------- 1.6/43.7 MB 167.1 kB/s eta 0:04:13
#    - -------------------------------------- 1.6/43.7 MB 166.8 kB/s eta 0:04:13
#    - -------------------------------------- 1.6/43.7 MB 166.8 kB/s eta 0:04:13
#    - -------------------------------------- 1.6/43.7 MB 166.8 kB/s eta 0:04:13
#    - -------------------------------------- 1.6/43.7 MB 166.5 kB/s eta 0:04:13
#    - -------------------------------------- 1.6/43.7 MB 167.5 kB/s eta 0:04:12
#    - -------------------------------------- 1.6/43.7 MB 167.5 kB/s eta 0:04:12
#    - -------------------------------------- 1.6/43.7 MB 167.5 kB/s eta 0:04:12
#    - -------------------------------------- 1.7/43.7 MB 168.8 kB/s eta 0:04:10
#    - -------------------------------------- 1.7/43.7 MB 169.3 kB/s eta 0:04:09
#    - -------------------------------------- 1.7/43.7 MB 169.3 kB/s eta 0:04:09
#    - -------------------------------------- 1.7/43.7 MB 170.0 kB/s eta 0:04:08
#    - -------------------------------------- 1.7/43.7 MB 170.0 kB/s eta 0:04:08
#    - -------------------------------------- 1.7/43.7 MB 170.0 kB/s eta 0:04:08
#    - -------------------------------------- 1.7/43.7 MB 171.2 kB/s eta 0:04:06
#    - -------------------------------------- 1.7/43.7 MB 171.2 kB/s eta 0:04:06
#    - -------------------------------------- 1.7/43.7 MB 171.2 kB/s eta 0:04:06
#    - -------------------------------------- 1.8/43.7 MB 171.7 kB/s eta 0:04:05
#    - -------------------------------------- 1.8/43.7 MB 171.7 kB/s eta 0:04:05
#    - -------------------------------------- 1.8/43.7 MB 171.7 kB/s eta 0:04:05
#    - -------------------------------------- 1.8/43.7 MB 170.3 kB/s eta 0:04:07
#    - -------------------------------------- 1.8/43.7 MB 170.3 kB/s eta 0:04:07
#    - -------------------------------------- 1.8/43.7 MB 170.3 kB/s eta 0:04:07
#    - -------------------------------------- 1.8/43.7 MB 170.3 kB/s eta 0:04:07
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 169.5 kB/s eta 0:04:08
#    - -------------------------------------- 1.8/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.8/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.8/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.8/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.8/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.8/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.8/43.7 MB 162.0 kB/s eta 0:04:19
#    - -------------------------------------- 1.8/43.7 MB 162.0 kB/s eta 0:04:19
#    - -------------------------------------- 1.8/43.7 MB 162.5 kB/s eta 0:04:18
#    - -------------------------------------- 1.8/43.7 MB 162.5 kB/s eta 0:04:18
#    - -------------------------------------- 1.8/43.7 MB 162.3 kB/s eta 0:04:19
#    - -------------------------------------- 1.9/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.4 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.2 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.2 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.8 kB/s eta 0:04:16
#    - -------------------------------------- 1.9/43.7 MB 163.8 kB/s eta 0:04:16
#    - -------------------------------------- 1.9/43.7 MB 163.8 kB/s eta 0:04:16
#    - -------------------------------------- 1.9/43.7 MB 163.8 kB/s eta 0:04:16
#    - -------------------------------------- 1.9/43.7 MB 163.8 kB/s eta 0:04:16
#    - -------------------------------------- 1.9/43.7 MB 163.2 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.2 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.2 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.2 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 163.2 kB/s eta 0:04:17
#    - -------------------------------------- 1.9/43.7 MB 161.7 kB/s eta 0:04:19
#    - -------------------------------------- 1.9/43.7 MB 162.6 kB/s eta 0:04:18
#    - -------------------------------------- 1.9/43.7 MB 162.6 kB/s eta 0:04:18
#    - -------------------------------------- 1.9/43.7 MB 162.6 kB/s eta 0:04:18
#    - -------------------------------------- 2.0/43.7 MB 161.7 kB/s eta 0:04:19
#    - -------------------------------------- 2.0/43.7 MB 161.7 kB/s eta 0:04:19
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:18
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:18
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:18
#    - -------------------------------------- 2.0/43.7 MB 162.8 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.8 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 162.4 kB/s eta 0:04:17
#    - -------------------------------------- 2.0/43.7 MB 158.8 kB/s eta 0:04:23
#    - -------------------------------------- 2.0/43.7 MB 158.8 kB/s eta 0:04:23
#    - -------------------------------------- 2.0/43.7 MB 158.8 kB/s eta 0:04:23
#    - -------------------------------------- 2.0/43.7 MB 158.8 kB/s eta 0:04:23
#    - -------------------------------------- 2.0/43.7 MB 158.8 kB/s eta 0:04:23
#    - -------------------------------------- 2.0/43.7 MB 157.3 kB/s eta 0:04:26
#    - -------------------------------------- 2.0/43.7 MB 157.3 kB/s eta 0:04:26
#    - -------------------------------------- 2.0/43.7 MB 157.3 kB/s eta 0:04:26
#    - -------------------------------------- 2.1/43.7 MB 157.3 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.3 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.3 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.3 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.2 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.2 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.2 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.2 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.2 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.2 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 157.2 kB/s eta 0:04:25
#    - -------------------------------------- 2.1/43.7 MB 154.9 kB/s eta 0:04:29
#    - -------------------------------------- 2.1/43.7 MB 154.9 kB/s eta 0:04:29
#    - -------------------------------------- 2.1/43.7 MB 154.9 kB/s eta 0:04:29
#    - -------------------------------------- 2.1/43.7 MB 154.9 kB/s eta 0:04:29
#    - -------------------------------------- 2.1/43.7 MB 154.9 kB/s eta 0:04:29
#    - -------------------------------------- 2.1/43.7 MB 154.9 kB/s eta 0:04:29
#    - -------------------------------------- 2.1/43.7 MB 154.1 kB/s eta 0:04:31
#    - -------------------------------------- 2.1/43.7 MB 154.1 kB/s eta 0:04:31
#    - -------------------------------------- 2.1/43.7 MB 154.1 kB/s eta 0:04:31
#    - -------------------------------------- 2.1/43.7 MB 154.1 kB/s eta 0:04:31
#    - -------------------------------------- 2.1/43.7 MB 153.2 kB/s eta 0:04:32
#    - -------------------------------------- 2.1/43.7 MB 153.2 kB/s eta 0:04:32
#    - -------------------------------------- 2.1/43.7 MB 153.2 kB/s eta 0:04:32
#    - -------------------------------------- 2.1/43.7 MB 153.2 kB/s eta 0:04:32
#    - -------------------------------------- 2.1/43.7 MB 153.2 kB/s eta 0:04:32
#    - -------------------------------------- 2.1/43.7 MB 152.3 kB/s eta 0:04:34
#    - -------------------------------------- 2.1/43.7 MB 152.3 kB/s eta 0:04:34
#    - -------------------------------------- 2.1/43.7 MB 152.3 kB/s eta 0:04:34
#    - -------------------------------------- 2.1/43.7 MB 152.3 kB/s eta 0:04:34
#    - -------------------------------------- 2.2/43.7 MB 152.2 kB/s eta 0:04:34
#    - -------------------------------------- 2.2/43.7 MB 152.2 kB/s eta 0:04:34
#    - -------------------------------------- 2.2/43.7 MB 152.2 kB/s eta 0:04:34
#    - -------------------------------------- 2.2/43.7 MB 152.2 kB/s eta 0:04:34
#    - -------------------------------------- 2.2/43.7 MB 151.3 kB/s eta 0:04:35
#    - -------------------------------------- 2.2/43.7 MB 151.3 kB/s eta 0:04:35
#    - -------------------------------------- 2.2/43.7 MB 151.3 kB/s eta 0:04:35
#    -- ------------------------------------- 2.2/43.7 MB 151.4 kB/s eta 0:04:35
#    -- ------------------------------------- 2.2/43.7 MB 151.4 kB/s eta 0:04:35
#    -- ------------------------------------- 2.2/43.7 MB 151.4 kB/s eta 0:04:35
#    -- ------------------------------------- 2.2/43.7 MB 151.4 kB/s eta 0:04:35
#    -- ------------------------------------- 2.2/43.7 MB 150.8 kB/s eta 0:04:36
#    -- ------------------------------------- 2.2/43.7 MB 150.8 kB/s eta 0:04:36
#    -- ------------------------------------- 2.2/43.7 MB 150.8 kB/s eta 0:04:36
#    -- ------------------------------------- 2.2/43.7 MB 151.1 kB/s eta 0:04:35
#    -- ------------------------------------- 2.2/43.7 MB 151.1 kB/s eta 0:04:35
#    -- ------------------------------------- 2.2/43.7 MB 151.5 kB/s eta 0:04:34
#    -- ------------------------------------- 2.2/43.7 MB 151.5 kB/s eta 0:04:34
#    -- ------------------------------------- 2.2/43.7 MB 151.5 kB/s eta 0:04:34
#    -- ------------------------------------- 2.2/43.7 MB 151.5 kB/s eta 0:04:34
#    -- ------------------------------------- 2.2/43.7 MB 151.5 kB/s eta 0:04:34
#    -- ------------------------------------- 2.3/43.7 MB 150.4 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.4 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.4 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.4 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.2 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.2 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.2 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.2 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 150.2 kB/s eta 0:04:36
#    -- ------------------------------------- 2.3/43.7 MB 149.2 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.2 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.2 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.2 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 149.0 kB/s eta 0:04:38
#    -- ------------------------------------- 2.3/43.7 MB 147.1 kB/s eta 0:04:42
#    -- ------------------------------------- 2.3/43.7 MB 147.1 kB/s eta 0:04:42
#    -- ------------------------------------- 2.3/43.7 MB 147.1 kB/s eta 0:04:42
#    -- ------------------------------------- 2.3/43.7 MB 147.1 kB/s eta 0:04:42
#    -- ------------------------------------- 2.3/43.7 MB 147.1 kB/s eta 0:04:42
#    -- ------------------------------------- 2.3/43.7 MB 147.1 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 146.4 kB/s eta 0:04:43
#    -- ------------------------------------- 2.4/43.7 MB 146.4 kB/s eta 0:04:43
#    -- ------------------------------------- 2.4/43.7 MB 146.4 kB/s eta 0:04:43
#    -- ------------------------------------- 2.4/43.7 MB 146.4 kB/s eta 0:04:43
#    -- ------------------------------------- 2.4/43.7 MB 145.8 kB/s eta 0:04:44
#    -- ------------------------------------- 2.4/43.7 MB 145.8 kB/s eta 0:04:44
#    -- ------------------------------------- 2.4/43.7 MB 146.5 kB/s eta 0:04:43
#    -- ------------------------------------- 2.4/43.7 MB 146.5 kB/s eta 0:04:43
#    -- ------------------------------------- 2.4/43.7 MB 146.9 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 146.9 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 146.9 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 146.5 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 146.5 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 146.5 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 146.9 kB/s eta 0:04:42
#    -- ------------------------------------- 2.4/43.7 MB 147.0 kB/s eta 0:04:41
#    -- ------------------------------------- 2.4/43.7 MB 147.0 kB/s eta 0:04:41
#    -- ------------------------------------- 2.5/43.7 MB 147.7 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.7 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.9 kB/s eta 0:04:39
#    -- ------------------------------------- 2.5/43.7 MB 147.9 kB/s eta 0:04:39
#    -- ------------------------------------- 2.5/43.7 MB 147.9 kB/s eta 0:04:39
#    -- ------------------------------------- 2.5/43.7 MB 147.9 kB/s eta 0:04:39
#    -- ------------------------------------- 2.5/43.7 MB 147.5 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.5 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.5 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.4 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.4 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.6 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 147.6 kB/s eta 0:04:40
#    -- ------------------------------------- 2.5/43.7 MB 148.3 kB/s eta 0:04:38
#    -- ------------------------------------- 2.6/43.7 MB 148.9 kB/s eta 0:04:37
#    -- ------------------------------------- 2.6/43.7 MB 148.9 kB/s eta 0:04:37
#    -- ------------------------------------- 2.6/43.7 MB 148.9 kB/s eta 0:04:37
#    -- ------------------------------------- 2.6/43.7 MB 148.9 kB/s eta 0:04:37
#    -- ------------------------------------- 2.6/43.7 MB 149.5 kB/s eta 0:04:36
#    -- ------------------------------------- 2.6/43.7 MB 149.7 kB/s eta 0:04:35
#    -- ------------------------------------- 2.6/43.7 MB 149.7 kB/s eta 0:04:35
#    -- ------------------------------------- 2.6/43.7 MB 150.3 kB/s eta 0:04:34
#    -- ------------------------------------- 2.6/43.7 MB 150.6 kB/s eta 0:04:33
#    -- ------------------------------------- 2.7/43.7 MB 150.7 kB/s eta 0:04:33
#    -- ------------------------------------- 2.7/43.7 MB 150.7 kB/s eta 0:04:33
#    -- ------------------------------------- 2.7/43.7 MB 151.3 kB/s eta 0:04:32
#    -- ------------------------------------- 2.7/43.7 MB 152.1 kB/s eta 0:04:30
#    -- ------------------------------------- 2.7/43.7 MB 152.1 kB/s eta 0:04:30
#    -- ------------------------------------- 2.7/43.7 MB 152.3 kB/s eta 0:04:30
#    -- ------------------------------------- 2.7/43.7 MB 152.3 kB/s eta 0:04:30
#    -- ------------------------------------- 2.7/43.7 MB 153.2 kB/s eta 0:04:28
#    -- ------------------------------------- 2.8/43.7 MB 153.8 kB/s eta 0:04:27
#    -- ------------------------------------- 2.8/43.7 MB 153.8 kB/s eta 0:04:27
#    -- ------------------------------------- 2.8/43.7 MB 154.5 kB/s eta 0:04:26
#    -- ------------------------------------- 2.8/43.7 MB 154.5 kB/s eta 0:04:26
#    -- ------------------------------------- 2.8/43.7 MB 154.4 kB/s eta 0:04:26
#    -- ------------------------------------- 2.8/43.7 MB 154.4 kB/s eta 0:04:26
#    -- ------------------------------------- 2.8/43.7 MB 154.2 kB/s eta 0:04:26
#    -- ------------------------------------- 2.8/43.7 MB 154.8 kB/s eta 0:04:25
#    -- ------------------------------------- 2.8/43.7 MB 154.8 kB/s eta 0:04:25
#    -- ------------------------------------- 2.8/43.7 MB 154.4 kB/s eta 0:04:25
#    -- ------------------------------------- 2.8/43.7 MB 154.4 kB/s eta 0:04:25
#    -- ------------------------------------- 2.8/43.7 MB 154.9 kB/s eta 0:04:25
#    -- ------------------------------------- 2.8/43.7 MB 154.9 kB/s eta 0:04:25
#    -- ------------------------------------- 2.9/43.7 MB 155.6 kB/s eta 0:04:23
#    -- ------------------------------------- 2.9/43.7 MB 155.6 kB/s eta 0:04:23
#    -- ------------------------------------- 2.9/43.7 MB 155.6 kB/s eta 0:04:23
#    -- ------------------------------------- 2.9/43.7 MB 156.2 kB/s eta 0:04:22
#    -- ------------------------------------- 2.9/43.7 MB 156.2 kB/s eta 0:04:22
#    -- ------------------------------------- 2.9/43.7 MB 156.2 kB/s eta 0:04:22
#    -- ------------------------------------- 2.9/43.7 MB 156.9 kB/s eta 0:04:21
#    -- ------------------------------------- 2.9/43.7 MB 157.5 kB/s eta 0:04:19
#    -- ------------------------------------- 2.9/43.7 MB 157.5 kB/s eta 0:04:19
#    -- ------------------------------------- 2.9/43.7 MB 157.5 kB/s eta 0:04:19
#    -- ------------------------------------- 3.0/43.7 MB 158.2 kB/s eta 0:04:18
#    -- ------------------------------------- 3.0/43.7 MB 158.5 kB/s eta 0:04:18
#    -- ------------------------------------- 3.0/43.7 MB 159.2 kB/s eta 0:04:16
#    -- ------------------------------------- 3.0/43.7 MB 160.0 kB/s eta 0:04:15
#    -- ------------------------------------- 3.0/43.7 MB 160.0 kB/s eta 0:04:15
#    -- ------------------------------------- 3.0/43.7 MB 159.9 kB/s eta 0:04:15
#    -- ------------------------------------- 3.1/43.7 MB 160.7 kB/s eta 0:04:14
#    -- ------------------------------------- 3.1/43.7 MB 160.7 kB/s eta 0:04:14
#    -- ------------------------------------- 3.1/43.7 MB 160.6 kB/s eta 0:04:14
#    -- ------------------------------------- 3.1/43.7 MB 160.6 kB/s eta 0:04:14
#    -- ------------------------------------- 3.1/43.7 MB 161.0 kB/s eta 0:04:13
#    -- ------------------------------------- 3.1/43.7 MB 161.0 kB/s eta 0:04:13
#    -- ------------------------------------- 3.1/43.7 MB 161.4 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.4 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.3 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.3 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.3 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 160.8 kB/s eta 0:04:13
#    -- ------------------------------------- 3.1/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.1/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.2/43.7 MB 161.0 kB/s eta 0:04:13
#    -- ------------------------------------- 3.2/43.7 MB 161.0 kB/s eta 0:04:13
#    -- ------------------------------------- 3.2/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.2/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.2/43.7 MB 161.2 kB/s eta 0:04:12
#    -- ------------------------------------- 3.2/43.7 MB 161.8 kB/s eta 0:04:11
#    -- ------------------------------------- 3.2/43.7 MB 161.8 kB/s eta 0:04:11
#    -- ------------------------------------- 3.2/43.7 MB 161.8 kB/s eta 0:04:11
#    -- ------------------------------------- 3.2/43.7 MB 162.6 kB/s eta 0:04:10
#    -- ------------------------------------- 3.2/43.7 MB 162.6 kB/s eta 0:04:10
#    -- ------------------------------------- 3.3/43.7 MB 162.8 kB/s eta 0:04:09
#    -- ------------------------------------- 3.3/43.7 MB 162.8 kB/s eta 0:04:09
#    -- ------------------------------------- 3.3/43.7 MB 162.8 kB/s eta 0:04:09
#    -- ------------------------------------- 3.3/43.7 MB 162.8 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 162.7 kB/s eta 0:04:09
#    --- ------------------------------------ 3.3/43.7 MB 159.4 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 159.4 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 159.4 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 158.9 kB/s eta 0:04:15
#    --- ------------------------------------ 3.3/43.7 MB 158.9 kB/s eta 0:04:15
#    --- ------------------------------------ 3.3/43.7 MB 159.2 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 159.2 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 159.2 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 159.2 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 159.2 kB/s eta 0:04:14
#    --- ------------------------------------ 3.3/43.7 MB 158.4 kB/s eta 0:04:15
#    --- ------------------------------------ 3.3/43.7 MB 158.4 kB/s eta 0:04:15
#    --- ------------------------------------ 3.3/43.7 MB 158.4 kB/s eta 0:04:15
#    --- ------------------------------------ 3.3/43.7 MB 158.4 kB/s eta 0:04:15
#    --- ------------------------------------ 3.3/43.7 MB 158.4 kB/s eta 0:04:15
#    --- ------------------------------------ 3.4/43.7 MB 157.8 kB/s eta 0:04:16
#    --- ------------------------------------ 3.4/43.7 MB 157.8 kB/s eta 0:04:16
#    --- ------------------------------------ 3.4/43.7 MB 157.8 kB/s eta 0:04:16
#    --- ------------------------------------ 3.4/43.7 MB 157.8 kB/s eta 0:04:16
#    --- ------------------------------------ 3.4/43.7 MB 157.8 kB/s eta 0:04:16
#    --- ------------------------------------ 3.4/43.7 MB 157.4 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 157.4 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 157.4 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 157.4 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 157.4 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 156.4 kB/s eta 0:04:18
#    --- ------------------------------------ 3.4/43.7 MB 156.4 kB/s eta 0:04:18
#    --- ------------------------------------ 3.4/43.7 MB 156.9 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 156.9 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 156.9 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 156.9 kB/s eta 0:04:17
#    --- ------------------------------------ 3.4/43.7 MB 156.5 kB/s eta 0:04:18
#    --- ------------------------------------ 3.4/43.7 MB 156.5 kB/s eta 0:04:18
#    --- ------------------------------------ 3.4/43.7 MB 156.5 kB/s eta 0:04:18
#    --- ------------------------------------ 3.4/43.7 MB 156.5 kB/s eta 0:04:18
#    --- ------------------------------------ 3.5/43.7 MB 156.2 kB/s eta 0:04:18
#    --- ------------------------------------ 3.5/43.7 MB 156.2 kB/s eta 0:04:18
#    --- ------------------------------------ 3.5/43.7 MB 156.2 kB/s eta 0:04:18
#    --- ------------------------------------ 3.5/43.7 MB 156.2 kB/s eta 0:04:18
#    --- ------------------------------------ 3.5/43.7 MB 156.2 kB/s eta 0:04:18
#    --- ------------------------------------ 3.5/43.7 MB 155.7 kB/s eta 0:04:19
#    --- ------------------------------------ 3.5/43.7 MB 155.7 kB/s eta 0:04:19
#    --- ------------------------------------ 3.5/43.7 MB 155.7 kB/s eta 0:04:19
#    --- ------------------------------------ 3.5/43.7 MB 155.7 kB/s eta 0:04:19
#    --- ------------------------------------ 3.5/43.7 MB 155.7 kB/s eta 0:04:19
#    --- ------------------------------------ 3.5/43.7 MB 154.9 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 154.9 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 154.9 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 154.9 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 154.9 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 154.9 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 154.8 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 154.8 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 155.0 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 155.0 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 155.0 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 155.0 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 155.0 kB/s eta 0:04:20
#    --- ------------------------------------ 3.5/43.7 MB 155.0 kB/s eta 0:04:20
#    --- ------------------------------------ 3.6/43.7 MB 154.5 kB/s eta 0:04:21
#    --- ------------------------------------ 3.6/43.7 MB 154.5 kB/s eta 0:04:21
#    --- ------------------------------------ 3.6/43.7 MB 154.5 kB/s eta 0:04:21
#    --- ------------------------------------ 3.6/43.7 MB 154.5 kB/s eta 0:04:21
#    --- ------------------------------------ 3.6/43.7 MB 154.5 kB/s eta 0:04:21
#    --- ------------------------------------ 3.6/43.7 MB 153.5 kB/s eta 0:04:22
#    --- ------------------------------------ 3.6/43.7 MB 153.5 kB/s eta 0:04:22
#    --- ------------------------------------ 3.6/43.7 MB 153.5 kB/s eta 0:04:22
#    --- ------------------------------------ 3.6/43.7 MB 153.5 kB/s eta 0:04:22
#    --- ------------------------------------ 3.6/43.7 MB 153.5 kB/s eta 0:04:22
#    --- ------------------------------------ 3.6/43.7 MB 153.5 kB/s eta 0:04:22
#    --- ------------------------------------ 3.6/43.7 MB 153.1 kB/s eta 0:04:23
#    --- ------------------------------------ 3.6/43.7 MB 153.1 kB/s eta 0:04:23
#    --- ------------------------------------ 3.6/43.7 MB 153.1 kB/s eta 0:04:23
#    --- ------------------------------------ 3.6/43.7 MB 153.1 kB/s eta 0:04:23
#    --- ------------------------------------ 3.6/43.7 MB 152.4 kB/s eta 0:04:24
#    --- ------------------------------------ 3.6/43.7 MB 152.4 kB/s eta 0:04:24
#    --- ------------------------------------ 3.6/43.7 MB 152.4 kB/s eta 0:04:24
#    --- ------------------------------------ 3.6/43.7 MB 152.4 kB/s eta 0:04:24
#    --- ------------------------------------ 3.6/43.7 MB 152.5 kB/s eta 0:04:24
#    --- ------------------------------------ 3.6/43.7 MB 152.5 kB/s eta 0:04:24
# ...
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:10
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:10
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:10
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.9 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.8/43.7 MB 107.6 kB/s eta 0:00:09
#    ---------------------------------------  42.9/43.7 MB 108.4 kB/s eta 0:00:09
#    ---------------------------------------  42.9/43.7 MB 108.4 kB/s eta 0:00:09
#    ---------------------------------------  42.9/43.7 MB 108.4 kB/s eta 0:00:09
#    ---------------------------------------  42.9/43.7 MB 108.6 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 108.6 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 108.6 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 108.5 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 108.5 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 108.5 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 109.5 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 109.6 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 109.6 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 110.0 kB/s eta 0:00:08
#    ---------------------------------------  42.9/43.7 MB 110.0 kB/s eta 0:00:08
#    ---------------------------------------  43.0/43.7 MB 110.4 kB/s eta 0:00:08
#    ---------------------------------------  43.0/43.7 MB 110.4 kB/s eta 0:00:08
#    ---------------------------------------  43.0/43.7 MB 110.3 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.3 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.3 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.3 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.3 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.3 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.0 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.0 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.0 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.0 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.8 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.8 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.8 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.8 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.8 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.8 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.7 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.7 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.7 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.6 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 110.6 kB/s eta 0:00:07
#    ---------------------------------------  43.0/43.7 MB 114.3 kB/s eta 0:00:06
#    ---------------------------------------  43.0/43.7 MB 114.3 kB/s eta 0:00:06
#    ---------------------------------------  43.0/43.7 MB 114.3 kB/s eta 0:00:06
#    ---------------------------------------  43.0/43.7 MB 114.3 kB/s eta 0:00:06
#    ---------------------------------------  43.0/43.7 MB 114.3 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.0 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.0 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.0 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.0 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.0 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.0 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.2 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.2 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.2 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.6 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.6 kB/s eta 0:00:06
#    ---------------------------------------  43.1/43.7 MB 114.6 kB/s eta 0:00:06
#    ---------------------------------------  43.2/43.7 MB 115.1 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.1 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.1 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.1 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.1 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.1 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.0 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.4 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 115.5 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 116.0 kB/s eta 0:00:05
#    ---------------------------------------  43.2/43.7 MB 116.0 kB/s eta 0:00:05
#    ---------------------------------------  43.3/43.7 MB 116.4 kB/s eta 0:00:05
#    ---------------------------------------  43.3/43.7 MB 116.5 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 116.5 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.1 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.4 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.4 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.4 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.4 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.0 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.0 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.0 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.3 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.3 kB/s eta 0:00:04
#    ---------------------------------------  43.3/43.7 MB 118.3 kB/s eta 0:00:04
#    ---------------------------------------  43.4/43.7 MB 119.2 kB/s eta 0:00:04
#    ---------------------------------------  43.4/43.7 MB 119.2 kB/s eta 0:00:04
#    ---------------------------------------  43.4/43.7 MB 119.2 kB/s eta 0:00:04
#    ---------------------------------------  43.4/43.7 MB 119.2 kB/s eta 0:00:04
#    ---------------------------------------  43.4/43.7 MB 119.2 kB/s eta 0:00:04
#    ---------------------------------------  43.4/43.7 MB 119.1 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.1 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.5 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.5 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.5 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.3 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.3 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.4 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.4 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 119.4 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 120.0 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 120.0 kB/s eta 0:00:03
#    ---------------------------------------  43.4/43.7 MB 120.0 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 119.9 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 119.9 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 119.9 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 120.0 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 120.0 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 120.0 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 119.9 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 119.9 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 119.9 kB/s eta 0:00:03
#    ---------------------------------------  43.5/43.7 MB 119.4 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 119.4 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 121.0 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 121.0 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 121.0 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.5/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.4 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.4 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.4 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.4 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.9 kB/s eta 0:00:02
#    ---------------------------------------  43.6/43.7 MB 120.4 kB/s eta 0:00:01
#    ---------------------------------------  43.6/43.7 MB 120.4 kB/s eta 0:00:01
#    ---------------------------------------  43.6/43.7 MB 120.4 kB/s eta 0:00:01
#    ---------------------------------------  43.6/43.7 MB 120.2 kB/s eta 0:00:01
#    ---------------------------------------  43.6/43.7 MB 120.2 kB/s eta 0:00:01
#    ---------------------------------------  43.6/43.7 MB 121.0 kB/s eta 0:00:01
#    ---------------------------------------  43.6/43.7 MB 121.0 kB/s eta 0:00:01
#    ---------------------------------------  43.6/43.7 MB 121.0 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 120.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 120.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 120.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 120.3 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 120.3 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 120.3 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 120.3 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.2 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.2 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.2 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.2 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.2 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.2 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 119.2 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------  43.7/43.7 MB 118.8 kB/s eta 0:00:01
#    ---------------------------------------- 43.7/43.7 MB 116.3 kB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.11.4

# %%
frame['a'].corr(frame['b'], method='spearman') # Metodo spearman
# Out:
# 0.04815865215865216

# %%
frame['a'].corr(frame['b'], method='kendall') # Metodo Kendall
# Out:
# 0.03234834834834835

# %%
frame.corr()
# Out:
#           a         b         c         d         e
# a  1.000000  0.056125  0.024210 -0.005499 -0.007650
# b  0.056125  1.000000  0.007777 -0.009033 -0.000781
# c  0.024210  0.007777  1.000000 -0.001434 -0.050740
# d -0.005499 -0.009033 -0.001434  1.000000 -0.043050
# e -0.007650 -0.000781 -0.050740 -0.043050  1.000000

# %%
# con Numpy
np.corrcoef(frame)
# Out:
# array([[ 1.        , -0.30647049, -0.65411155, ...,  0.29616673,
#          0.29013432, -0.83433691],
#        [-0.30647049,  1.        ,  0.02183588, ...,  0.71342068,
#         -0.59432049, -0.22950743],
#        [-0.65411155,  0.02183588,  1.        , ..., -0.66660793,
#         -0.63905691,  0.61597841],
#        ...,
#        [ 0.29616673,  0.71342068, -0.66660793, ...,  1.        ,
#         -0.0088048 , -0.63793483],
#        [ 0.29013432, -0.59432049, -0.63905691, ..., -0.0088048 ,
#          1.        ,  0.11039718],
#        [-0.83433691, -0.22950743,  0.61597841, ..., -0.63793483,
#          0.11039718,  1.        ]])

# %% [markdown]
# ### Funciones agregadas
# permite aplicar una o mas funciones en cada columna

# %%
df.agg(['sum', 'min'])

# %%
# Aplicar los metodos en columnas especificas
df[['col1','col2']].agg(['sum', 'min'])
# Out:
#      col1  col2
# sum    10  2109
# min     1   444

# %% [markdown]
# ### Aplicando funciones a cada elemento

# %%
#definicion de funcion
def times2(x:float)->float:
    return x*2

# %%
# es mas o menos lo que hace la funcion map
# aplicar la funcion times2 a cada elemento de la col1 de dataframe df
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len) #longitud de cada uno de los datos de la col3
# Out:
# 0    7
# 1    6
# 2    9
# 3    4
# Name: col3, dtype: int64

# %%
df['col1'].sum() #sumatoria total de los elementos de la col1
# Out:
# 10

# %% [markdown]
# #### Ordenando un dataframe

# %%
df
# Out:
#    col1  col2       col3
# 0     1   444    mama
# 1     2   555       papa
# 2     3   666     HIJO
# 3     4   444       HiJa

# %%
# ordenar el dataframe de menor a mayor basado en col2
df.sort_values(by='col2') #inplace=False por default
# Out:
#    col1  col2       col3
# 0     1   444    mama
# 3     4   444       HiJa
# 1     2   555       papa
# 2     3   666     HIJO

# %%
df.sort_values(by='col2',ascending=False)
# Out:
#    col1  col2       col3
# 2     3   666     HIJO
# 1     2   555       papa
# 0     1   444    mama
# 3     4   444       HiJa

# %% [markdown]
# ### Metodos de string
# Los metodos de string no son inplace

# %%
df
# Out:
#    col1  col2       col3
# 0     1   444    mama
# 1     2   555       papa
# 2     3   666     HIJO
# 3     4   444       HiJa

# %%
# convertir strings en minuscula
df['col3'].str.lower()
# Out:
# 0      mama
# 1         papa
# 2       hijo
# 3         hija
# Name: col3, dtype: object

# %%
# Eliminar los espacios de los strings
df['col3'].str.strip()
# Out:
# 0    mama
# 1    papa
# 2    HIJO
# 3    HiJa
# Name: col3, dtype: object

# %% [markdown]
# ### Transformacion de variables
# * Crear variables Dummy: convertir de categoría a númerica
# * Discretización o Binning: convertir de número a categoría

# %% [markdown]
# #### Columnas dummy

# %%
# crear datos categoricos
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
        'sex': ['male', 'female', 'male', 'female', 'female']}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'sex'])
df
# Out:
#   first_name last_name     sex
# 0      Jason    Miller    male
# 1      Molly  Jacobson  female
# 2       Tina       Ali    male
# 3       Jake    Milner  female
# 4        Amy     Cooze  female

# %%
# Crear un set de variables dummy para la columna sex
df_sex = pd.get_dummies(df['sex'])
df_sex
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2   False   True
# 3    True  False
# 4    True  False

# %%
# unir los dos dataframes
df_new = df.join(df_sex)
df_new
# Out:
#   first_name last_name     sex  female   male
# 0      Jason    Miller    male   False   True
# 1      Molly  Jacobson  female    True  False
# 2       Tina       Ali    male   False   True
# 3       Jake    Milner  female    True  False
# 4        Amy     Cooze  female    True  False

# %% [markdown]
# #### Discretizacion o binning

# %%
# dividir los datos en 3 rangos iguales (categorias)

pd.cut(np.array([3.5, 2.8, 1, 5, 3, 4, 0, 4.4, 2, 3]), 3)
# Out:
# [(3.333, 5.0], (1.667, 3.333], (-0.005, 1.667], (3.333, 5.0], (1.667, 3.333], (3.333, 5.0], (-0.005, 1.667], (3.333, 5.0], (1.667, 3.333], (1.667, 3.333]]
# Categories (3, interval[float64, right]): [(-0.005, 1.667] < (1.667, 3.333] < (3.333, 5.0]]

# %%
# Asignar etiquetas ordenadas
pd.cut(np.array([3.5, 2.8, 1, 5, 3, 4,0, 4.4, 2, 3]),
        3, labels=["Malo", "Regular", "Bien"])
# Out:
# ['Bien', 'Regular', 'Malo', 'Bien', 'Regular', 'Bien', 'Malo', 'Bien', 'Regular', 'Regular']
# Categories (3, object): ['Malo' < 'Regular' < 'Bien']

# %%
pd.cut(np.array([2, 4 , 10 , 35 , 25 , 60 , 23, 14]),
        3, labels=["Niño", "Adolescente", "Adulto"])
# Out:
# ['Niño', 'Niño', 'Niño', 'Adolescente', 'Adolescente', 'Adulto', 'Adolescente', 'Niño']
# Categories (3, object): ['Niño' < 'Adolescente' < 'Adulto']

# %% [markdown]
# ### Leer y guardar datos (Data inputs and outputs)
# Pandas puede leer una variedad de archivos usando sus metodos pd.read_
#
# * CSV
# * Parquet
# * Excel
# * JSON
# * html
# * SQL

# %% [markdown]
# #### CSV

# %%
# Leer
df_supermarket_csv = pd.read_csv('supermarkets.csv')
df_supermarket_csv

# guardar
# Grabar el dataframe como archivo separado por comas
df_supermarket_csv.to_csv('example_out.csv',index=False)

# %% [markdown]
# #### Parquet
# Este es un formato de archivo binario de columna que es muy bueno para compartir datos. Es muy eficiente en el espacio y el tiempo de lectura.
#
# Es el formato recomendado para compartir datos.
#
# Para poder usarlo con pandas 1.5.3 es necesario instalar la libreria pyarrow
#
# pip install pyarrow
#
# Con la nueva version de pandas 2.x.x ya no es necesario instalar la libreria pyarrow

# %%
# Leer archivos separados por comas, extension .csv
df_supermarket_parquet = pd.read_parquet('supermarkets.parquet')
df_supermarket_parquet
# Grabar el dataframe como archivo parquet
df_supermarket_parquet.to_parquet('example_out.parquet')

# %% [markdown]
# #### Archivo de texto separado por otro caracter

# %%
# este archivo los valores estan separados por ;
df_supermarket = pd.read_csv("supermarkets-semi-colons.txt",sep=';')
df_supermarket

# %% [markdown]
# #### Excel
# Pandas solo puede importar datos, si el archivo tiene formulas, imagenes o macros puede hacer que se bloquee.

# %%
# leer un archivo de excel
df2 = pd.read_excel("supermarkets.xlsx",sheet_name=0) #leer la primera hoja del archivo
df2
df2.to_excel('Excel_Sample_out.xlsx',sheet_name='Hoja1')

# %% [markdown]
# #### JSON

# %%
# los archivos pueden estar en un link de internet
df4 = pd.read_json("http://pythonhow.com/supermarkets.json")
df4
#Para grabar
df4.to_json("Salida.json")

# %% [markdown]
# #### HTML

# %%
data = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %% [markdown]
# #### SQL
# El módulo pandas.io.sql proporciona una colección de contenedores de consultas para facilitar la recuperación de datos y reducir la dependencia de la API específica de DB. La abstracción de la base de datos es proporcionada por SQLAlchemy si está instalado. Además, necesitará una biblioteca de controladores para su base de datos. Ejemplos de tales controladores son psycopg2 para PostgreSQL o pymysql para MySQL. Para SQLite esto está incluido en la biblioteca estándar de Python por defecto.

# %% [markdown]
# read_sql_table(table_name, con[, schema, …])
# Read SQL database table into a DataFrame.
# read_sql_query(sql, con[, index_col, …])
# Read SQL query into a DataFrame.
# read_sql(sql, con[, index_col, …])
# Read SQL query or database table into a DataFrame.
# DataFrame.to_sql(name, con[, flavor, …])
# Write records stored in a DataFrame to a SQL database.

# %%
# librerias para crear un proceso de sql sencillo
from sqlalchemy import create_engine
# crear un proceso en memoria
engine = create_engine('sqlite:///:memory:')
df4.to_sql('data', engine) # grabar el dataframe en formato sql
sql_df = pd.read_sql('data',con=engine) # definir la conexion
sql_df
